# %% [markdown]
# ### Truncatable primes
#
# The number 3797 has an interesting property. Being prime itself, it is possible to continuously remove digits from left to right, and remain prime at each stage: 3797, 797, 97, and 7. Similarly we can work from right to left: 3797, 379, 37, and 3.
#
# Find the sum of the only eleven primes that are both truncatable from left to right and right to left.
#
# NOTE: 2, 3, 5, and 7 are not considered to be truncatable primes.

# %% [markdown]
# Szóval azt a 11 darab nagy prímszámot keresünk, amiből levagdosva elejéről és végéről is prímet kapunk.
# Érdemes lehet hátulról nekiállni és úgy keresni prímeket amik elöl hátul bővíthetőek.
# Szabad az interneten kutatni a feladathoz, prím eldöntő függvényt vagy hasonlókat.

# %% [markdown]
# ------------------------------------

# %% [markdown]
# - Elsőre biztos írnék egy függvényt (vagy találnék egyet), ami eldönti tetszőleges számról hogy prím-e.
# - Ha van egy ilyenem, akkor tuti elkezdenék egyjegyű prímeket hízlalni (először mondjuk csak az elejükre pakolva számokat) és így keresni elölről csonkítható prímeket.
# - Aztán belekeverném hogy hátulról is csonkítható legyen és összegyűjteném mind a tizenegyet.

# %% [markdown]
# https://stackoverflow.com/questions/18833759/prime-number-check-acts-strange ez az egyik leghasznosabb oldal, ez egy fórum, ahol minden programozós kérdésre van valami okosság. Felül van mindig a kérdés, ha valakinek valami nem működik, és alatta lesz mindig egy okos ember aki már megválaszolta a múltban.
